# %%
import xarray as xr

import oceanspy as ospy
fpath = 'C:\Master\data\sCoast_surface_data/SINMOD_samp.nc'
ds = xr.open_dataset(fpath)
od = ospy.OceanDataset(ds)

from dask.distributed import Client
client = Client()
client
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\Oceanography\lib\site-packages\xarray\backends\file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     197             try:
# --> 198                 file = self._cache[self._key]
#     199             except KeyError:
#
# ~\AppData\Local\Continuum\anaconda3\envs\Oceanography\lib\site-packages\xarray\backends\lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<function _open_scipy_netcdf at 0x00000220B4963798>, ('C:\\Master\\data\\sCoast_surface_data\\SINMOD_samp.nc',), 'r', (('mmap', None), ('version', 2))]
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\Oceanography\lib\site-packages\xarray\backends\scipy_.py in _open_scipy_netcdf(filename, mode, mmap, version)
#      82     try:
# ---> 83         return scipy.io.netcdf_file(filename, mode=mode, mmap=mmap, version=version)
#      84     except TypeError as e:  # netcdf3 message is obscure in this case
#
# ~\AppData\Local\Continuum\anaconda3\envs\Oceanography\lib\site-packages\scipy\io\netcdf.py in __init__(self, filename, mode, mmap, version, maskandscale)
#     283         if mode in 'ra':
# --> 284             self._read()
#     285
#
# ~\AppData\Local\Continuum\anaconda3\envs\Oceanography\lib\site-packages\scipy\io\netcdf.py in _read(self)
#     608             raise TypeError("Error: %s is not a valid NetCDF 3 file" %
# --> 609                             self.filename)
#     610         self.__dict__['version_byte'] = frombuffer(self.fp.read(1), '>b')[0]
#
# TypeError: Error: C:\Master\data\sCoast_surface_data\SINMOD_samp.nc is not a valid NetCDF 3 file
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-7f4c2764ea77> in <module>
#       3 import oceanspy as ospy
#       4 fpath = 'C:\Master\data\sCoast_surface_data/SINMOD_samp.nc'
# ----> 5 ds = xr.open_dataset(fpath)
#       6 od = ospy.OceanDataset(ds)
#       7
#
# ~\AppData\Local\Continuum\anaconda3\envs\Oceanography\lib\site-packages\xarray\backends\api.py in open_dataset(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, autoclose, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime)
#     533
#     534     with close_on_error(store):
# --> 535         ds = maybe_decode_store(store)
#     536
#     537     # Ensure source filename always stored in dataset object (GH issue #2550)
#
# ~\AppData\Local\Continuum\anaconda3\envs\Oceanography\lib\site-packages\xarray\backends\api.py in maybe_decode_store(store, lock)
#     448             decode_coords=decode_coords,
#     449             drop_variables=drop_variables,
# --> 450             use_cftime=use_cftime,
#     451         )
#     452
#
# ~\AppData\Local\Continuum\anaconda3\envs\Oceanography\lib\site-packages\xarray\conventions.py in decode_cf(obj, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime)
#     568         encoding = obj.encoding
#     569     elif isinstance(obj, AbstractDataStore):
# --> 570         vars, attrs = obj.load()
#     571         extra_coords = set()
#     572         file_obj = obj
#
# ~\AppData\Local\Continuum\anaconda3\envs\Oceanography\lib\site-packages\xarray\backends\common.py in load(self)
#     121         """
#     122         variables = FrozenDict(
# --> 123             (_decode_variable_name(k), v) for k, v in self.get_variables().items()
#     124         )
#     125         attributes = FrozenDict(self.get_attrs())
#
# ~\AppData\Local\Continuum\anaconda3\envs\Oceanography\lib\site-packages\xarray\backends\scipy_.py in get_variables(self)
#     155     def get_variables(self):
#     156         return FrozenDict(
# --> 157             (k, self.open_store_variable(k, v)) for k, v in self.ds.variables.items()
#     158         )
#     159
#
# ~\AppData\Local\Continuum\anaconda3\envs\Oceanography\lib\site-packages\xarray\backends\scipy_.py in ds(self)
#     144     @property
#     145     def ds(self):
# --> 146         return self._manager.acquire()
#     147
#     148     def open_store_variable(self, name, var):
#
# ~\AppData\Local\Continuum\anaconda3\envs\Oceanography\lib\site-packages\xarray\backends\file_manager.py in acquire(self, needs_lock)
#     178         An open file object, as returned by ``opener(*args, **kwargs)``.
#     179         """
# --> 180         file, _ = self._acquire_with_cache_info(needs_lock)
#     181         return file
#     182
#
# ~\AppData\Local\Continuum\anaconda3\envs\Oceanography\lib\site-packages\xarray\backends\file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     202                     kwargs = kwargs.copy()
#     203                     kwargs["mode"] = self._mode
# --> 204                 file = self._opener(*self._args, **kwargs)
#     205                 if self._mode == "w":
#     206                     # ensure file doesn't get overriden when opened again
#
# ~\AppData\Local\Continuum\anaconda3\envs\Oceanography\lib\site-packages\xarray\backends\scipy_.py in _open_scipy_netcdf(filename, mode, mmap, version)
#      92             """
#      93             errmsg += msg
# ---> 94             raise TypeError(errmsg)
#      95         else:
#      96             raise
#
# TypeError: Error: C:\Master\data\sCoast_surface_data\SINMOD_samp.nc is not a valid NetCDF 3 file
#             If this is a NetCDF4 file, you may need to install the
#             netcdf4 library, e.g.,
#
#             $ pip install netcdf4

# %%
# Plot the original domain
# %matplotlib inline
ax = od.plot.horizontal_section(varName='Depth')
title = ax.set_title(od.name)
