# %%
import xarray as xr
import numpy as np
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# single file
fpath = 'C:\Master\data\sCoast_surface_data/SINMOD_samp.nc'
ds = xr.open_dataset(fpath)

lat = ds.gridLats
lon = ds.gridLons

#test = sst.isel(xc=0, yc=0)
#test = sst.isel(time=0)
#print(test)
#test.plot()
#fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(9,3))
#test.plot.scatter()

# %%
sst = ds.temperature[0] 
sst_masked = sst.where(sst > -1e+4)

fig=plt.figure(figsize=(14, 12), dpi= 80, facecolor='w', edgecolor='w')

numcols, numrows = 1000, 1000
xi = np.linspace(lon.min(), lon.max(), numcols)
yi = np.linspace(lat.min(), lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)

#sst_masked.plot.contour(xi, yi, vmin=2, add_colorbar=True)

from matplotlib.mlab import griddata

#-- Interpolate at the points in xi, yi
# "griddata" expects "raw" numpy arrays, so we'll pass in
# data.x.values instead of just the pandas series data.x
x, y, z = lon.values, lat.values, sst_masked.values
zi = griddata(x, y, z, xi, yi)

#-- Display the results
fig, ax = plt.subplots()
im = ax.contourf(xi, yi, zi)
ax.scatter(data.Lon, data.Lat, c=data.Z, s=100,
           vmin=zi.min(), vmax=zi.max())
fig.colorbar(im)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-96ffbfc95624> in <module>
#       5
#       6
# ----> 7 xi = np.linspace(data.Lon.min(), data.Lon.max(), numcols)
#       8 yi = np.linspace(data.Lat.min(), data.Lat.max(), numrows)
#       9 xi, yi = np.meshgrid(xi, yi)
#
# NameError: name 'data' is not defined

# %%
"""
Python matplotlib / basemap example:  matplotlib_contour_lines.py

   - contour lines over map plot
   - rectilinear grid (lat/lon)
   - colorbar
   
   12.06.15  meier-fleischer(at)dkrz.de
"""
from   mpl_toolkits.basemap import Basemap, cm
import matplotlib.pyplot as plt
from   netCDF4 import Dataset as open_ncfile
import numpy as np

#-- open netcdf file
#nc = open_ncfile('/work/kv0653/NCL_Tutorial/data/ECHAM5_OM_A1B_2001_2D.nc')

#-- create figure and axes instances
fig = plt.figure(figsize=(8,8))
ax  = fig.add_axes([0.1,0.1,0.8,0.9])

#-- create map
map = Basemap(projection='cyl',llcrnrlat= -90.,urcrnrlat= 90.,\
              resolution='c',  llcrnrlon=-180.,urcrnrlon=180.)

#-- draw coastlines, state and country boundaries, edge of map
map.drawcoastlines()
map.drawstates()
map.drawcountries()

#-- create and draw meridians and parallels grid lines
map.drawparallels(np.arange( -90., 90.,30.),labels=[1,0,0,0],fontsize=10)
map.drawmeridians(np.arange(-180.,180.,30.),labels=[0,0,0,1],fontsize=10)

#-- convert latitude/longitude values to plot x/y values
x, y = map(*np.meshgrid(lon,lat))

#-- contour levels
clevs = np.arange(210,320,5)

#-- draw filled contours
cnplot = map.contour(x,y,sst,clevs,cmap=plt.cm.jet)

#-- add colorbar
cbar = map.colorbar(cnplot)                    #-- pad: distance between map and colorbar
cbar.set_label('deg K')                        #-- add colorbar title string

#-- add plot title
plt.title('Temperature')

#-- display on screen
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-4-7570b3ad8212> in <module>
#      34
#      35 #-- convert latitude/longitude values to plot x/y values
# ---> 36 x, y = map(*np.meshgrid(lon,lat))
#      37
#      38 #-- contour levels
#
# <__array_function__ internals> in meshgrid(*args, **kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\envs\oceanography\lib\site-packages\numpy\lib\function_base.py in meshgrid(*xi, **kwargs)
#    4214
#    4215     if copy_:
# -> 4216         output = [x.copy() for x in output]
#    4217
#    4218     return output
#
# ~\AppData\Local\Continuum\anaconda3\envs\oceanography\lib\site-packages\numpy\lib\function_base.py in <listcomp>(.0)
#    4214
#    4215     if copy_:
# -> 4216         output = [x.copy() for x in output]
#    4217
#    4218     return output
#
# ...

# %%
lon
# Out:
# <xarray.DataArray 'gridLons' (yc: 965, xc: 705)>
# array([[ 9.255215,  9.263374,  9.271542, ..., 15.695953, 15.706226, 15.716503],
#        [ 9.245903,  9.254074,  9.262234, ..., 15.686607, 15.696877, 15.707153],
#        [ 9.236595,  9.244759,  9.252922, ..., 15.677254, 15.687527, 15.6978  ],
#        ...,
#        [-1.008408, -1.001133, -0.993862, ...,  4.960552,  4.970467,  4.980385],
#        [-1.020512, -1.013237, -1.005962, ...,  4.947384,  4.957291,  4.967209],
#        [-1.032616, -1.025349, -1.018082, ...,  4.934204,  4.944115,  4.954029]],
#       dtype=float32)
# Coordinates:
#   * xc       (xc) float32 800.0 1600.0 2400.0 ... 562400.0 563200.0 564000.0
#   * yc       (yc) float32 800.0 1600.0 2400.0 ... 770400.0 771200.0 772000.0
# Attributes:
#     SINMODVarID:          22
#     units:                degrees_east
#     standard_name:        longitude
#     axis:                 X
#     _CoordinateAxisType:  Lon

# %%
conda install -y basemap

# %%
salinity = ds.salinity[0] 
salinity_masked = salinity.where(sst > -1e+4)
fig=plt.figure(figsize=(14, 12), dpi= 80, facecolor='w', edgecolor='k')
salinity_masked.plot(vmin=33)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                    (time: 3821, xc: 705, yc: 965, zc: 1)
# Coordinates:
#   * time                       (time) datetime64[ns] 2018-04-02 ... 2018-09-08T04:00:00
#   * xc                         (xc) float32 800.0 1600.0 ... 563200.0 564000.0
#   * yc                         (yc) float32 800.0 1600.0 ... 771200.0 772000.0
#   * zc                         (zc) float32 3.0
# Data variables:
#     grid_mapping               int32 ...
#     LayerDepths                (zc) float32 ...
#     depth                      (yc, xc) float32 ...
#     DXxDYy                     (yc, xc) float32 ...
#     gridLats                   (yc, xc) float32 ...
#     gridLons                   (yc, xc) float32 ...
#     u-velocity                 (time, yc, xc) float32 ...
#     v-velocity                 (time, yc, xc) float32 ...
#     temperature                (time, yc, xc) float32 ...
#     salinity                   (time, yc, xc) float32 ...
# ...

# %%
elevation = ds.elevation[0] 
elevation_masked = elevation.where(sst > -1e+4)
fig=plt.figure(figsize=(10,8), dpi= 80, facecolor='w', edgecolor='k')
#elevation_masked.coords['gridLats'] = lat
elevation_masked.plot.pcolormesh(vmin=0, vmax=1)#, x='gridLons', y='gridLats')

# %%
lon
# Out:
# <xarray.DataArray 'gridLats' (yc: 965, xc: 705)>
# [680325 values with dtype=float32]
# Coordinates:
#   * xc       (xc) float32 800.0 1600.0 2400.0 ... 562400.0 563200.0 564000.0
#   * yc       (yc) float32 800.0 1600.0 2400.0 ... 770400.0 771200.0 772000.0
# Attributes:
#     SINMODVarID:          21
#     units:                degrees_north
#     standard_name:        latitude
#     axis:                 Y
#     _CoordinateAxisType:  Lat

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                    (time: 3821, xc: 705, yc: 965, zc: 1)
# Coordinates:
#   * time                       (time) datetime64[ns] 2018-04-02 ... 2018-09-08T04:00:00
#   * xc                         (xc) float32 800.0 1600.0 ... 563200.0 564000.0
#   * yc                         (yc) float32 800.0 1600.0 ... 771200.0 772000.0
#   * zc                         (zc) float32 3.0
# Data variables:
#     grid_mapping               int32 ...
#     LayerDepths                (zc) float32 ...
#     depth                      (yc, xc) float32 ...
#     DXxDYy                     (yc, xc) float32 ...
#     gridLats                   (yc, xc) float32 ...
#     gridLons                   (yc, xc) float32 ...
#     u-velocity                 (time, yc, xc) float32 ...
#     v-velocity                 (time, yc, xc) float32 ...
#     temperature                (time, yc, xc) float32 ...
#     salinity                   (time, yc, xc) float32 ...
# ...

# %%
u = ds['u-velocity'][0]
u_masked = u.where(sst > -1e+4)
fig=plt.figure(figsize=(9,6), dpi= 80, facecolor='w', edgecolor='k')
u_masked.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-7e21d62a71c3> in <module>
#       1 u = ds['u-velocity'][0]
# ----> 2 u_masked = u.where(sst > -1e+4)
#       3 fig=plt.figure(figsize=(9,6), dpi= 80, facecolor='w', edgecolor='k')
#       4 u_masked.plot()
#
# NameError: name 'sst' is not defined

# %%
u = ds['u-velocity'][0]
v = ds['v-velocity'][0]
u_masked = u.where(u > -1e+4)
v_masked = v.where(v > -1e+4)

with np.errstate(all='ignore'):
    phase_angle = xr.ufuncs.rad2deg( xr.ufuncs.arctan2(v_masked, u_masked) ) + 180
    
fig=plt.figure(figsize=(10,8), dpi= 80, facecolor='w', edgecolor='k')
phase_angle.plot()

# %%
#phase_angle.rename('phase_angle')
phase_angle.to_netcdf('C:\Master\data\phase_angle_test.nc')

# %%
sst = ds.temperature[0] 
sst_masked = sst.where(sst > -1e+4)

fig=plt.figure(figsize=(10,8), dpi= 80, facecolor='w', edgecolor='w')
sst_masked.plot(vmin=2)

# %%
v_masked
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 3821, xc: 705, yc: 965)
# Coordinates:
#   * time         (time) datetime64[ns] 2018-04-02 ... 2018-09-08T04:00:00
#   * xc           (xc) float32 800.0 1600.0 2400.0 ... 562400.0 563200.0 564000.0
#   * yc           (yc) float32 800.0 1600.0 2400.0 ... 770400.0 771200.0 772000.0
# Data variables:
#     temperature  (yc, xc, time) float32
